# %%
#Initialize modules
import pandas
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (25, 10)

#Import data
ramen_ratings = pandas.read_csv("ramen-ratings.csv", index_col="review")
ramen_ratings = ramen_ratings.sort_values(by=['review']) #Because the list was unsorted
ramen_ratings['stars'] = pandas.to_numeric(ramen_ratings['stars'], errors='coerce') #Convert strings to floats for the stars rating

# %%
countries = ramen_ratings["country"].value_counts()

# %%
countries['Japan']
# Out:
# 398

# %%
is_5_star = ramen_ratings['stars'] == 5

# %%
five_stars = ramen_ratings[is_5_star]

# %%
five_stars
# Out:
#                   brand                                            variety  \
# review
# 13      Sapporo Ichiban                                          Chow Mein
# 28               Nissin                                       Chikin Ramen
# 45              Indomie                                     Mi Goreng Sate
# 47              Indomie                   Mi Goreng Jumbo Barbecue Chicken
# 50              Indomie                                          Mi Goreng
# 51              Indomie                 Curly Noodles With Grilled Chicken
# 105             Indomie                         Special Fried Curly Noodle
# 124              Nissin            Yakisoba With Mayonnaise/Mustard Packet
# 136                Mama                              Shrimp Creamy Tom Yum
# 140                Mama                                          Mi Goreng
# 147             Higashi                                 Nagasaki Sara Udon
# 232             Indomie                               Mi Goreng Jumbo Beef
# 236                Koka                                       Spicy Sesame
# 300               Wu Mu                     Steam Spinach Ramen With Onion
# 337            Maruchan                   Ramen Noodle Soup Creamy Chicken
# 370                Fuku                                      Superior Soup
# 392              Nissin                           Yakisoba Noodles Karashi
# 427                Koka                             Mi Hai Cua Crab Flavor
# 430           Quickchow                           Pancit Canton toyo Mansi
# 460             Menraku                                       Tempura Udon
# 490             Foodmon                  DJ DOC Instant rice Ramen Topokki
# 547           Lucky Me!                          Pancit Canton Sweet Spicy
# 566             Foodmon                                   DJ DOC Jjolmyeon
# 608                Koka                                 Spicy Black Pepper
# 639              Nissin                                 Gozen Kitsune Udon
# 652     Sapporo Ichiban                                               Shio
# 674               Paldo                                       Kko Kko Myun
# 700              Nissin                               Chikin Ramen (Local)
# 715             Indomie                         Mi Goreng Rendang (Import)
# 723             Indomie                         Mi Goreng Barbecue Chicken
# ...                 ...                                                ...
# 2608           Nona Lim             Hakata Ramen + Thai Curry & Lime Broth
# 2613             Nissin                      Raoh Backfat Rich Shoyu Ramen
# 2615             Nissin  Demae Ramen Straight Noodle Spicy Tonkotsu Fla...
# 2617             Nissin                          Cup Noodles Laksa Flavour
# 2618               KOKA     Delight Curry Flavor Instant Non-Fried Noodles
# 2625             Nissin   Cup Noodles Potato Chips Tom Yam Seafood Flavour
# 2627             Nissin                     Men Shokunin Sesame Miso Ramen
# 2644             Ottogi                                 Budae Jjigae Ramen
# 2645       Happy Noodle   Noodles Wirh Minced Pork & Chinese Mustard Blend
# 2651             Alhami                                  Mi Goreng Spesial
# 2663             Alhami                        Instant Noodle Soto Flavour
# 2672            Wei Lih                             Roast Beef Stew Noodle
# 2673             Nissin  Demae Ramen Bar Noodle Hokkaido Miso Tonkotsu ...
# 2676           Maruchan       Bowl Taste Of Asia Tom Yum Ramen Noodle Soup
# 2679            MyKuali                          Penang White Curry Noodle
# 2687             Nissin                           Yakisoba With Mayonnaise
# 2688               KOKA        Silk Laksa Singapura Instant Rice Fettucine
# 2691             Nissin  Demae Ramen Straight Noodle Shoyu Tonkotsu Ins...
# 2696           Nongshim                  Neoguri Spicy Seafood Noodle Soup
# 2706            Wei Lih                     GGE Ramen Snack Tempura Flavor
# 2708           Qinsheng                  Dumpling Pastry Hot & Sour Noodle
# 2710             Itsuki                Kyushu "Tonkotsu" Pork Flavor Ramen
# 2712              Maggi     2 Minute Noodles Masala Spicy (Export Version)
# 2730        Little Cook            Braised Beef Noodles With Tendon & Meat
# 2738             Meimen                                Tomato Noodles Soup
# 2741            MyKuali            Penang White Curry Noodle (2018 Recipe)
# 2744              Myojo                 Charumera Non-Fried Tonkotsu Ramen
# 2745             Nissin                  U. F. O. BIG Wasabi-Mayo Yakisoba
# 2748            MyKuali      Penang Red Tom Yum Goong Noodle (2018 Recipe)
# 2750             Nissin     Cup Noodles Tom Yum Goong Flavour Potato Chips
#
#        style        country  stars   top_ten
# review
# 13      Pack          Japan    5.0   2012 #4
# 28      Pack          Japan    5.0       NaN
# 45      Pack      Indonesia    5.0       NaN
# 47      Pack      Indonesia    5.0   2012 #2
# 50      Pack      Indonesia    5.0       NaN
# 51      Pack      Indonesia    5.0       NaN
# 105     Pack      Indonesia    5.0   2012 #1
# 124     Tray          Japan    5.0       NaN
# 136     Pack       Thailand    5.0       NaN
# 140     Pack       Thailand    5.0       NaN
# 147     Pack          Japan    5.0       NaN
# 232     Pack      Indonesia    5.0       NaN
# 236     Pack      Singapore    5.0       NaN
# 300     Pack         Taiwan    5.0       NaN
# 337     Pack  United States    5.0       NaN
# 370     Pack      Hong Kong    5.0       NaN
# 392     Tray          Japan    5.0   2012 #3
# 427     Pack      Singapore    5.0       NaN
# 430     Pack    Philippines    5.0       NaN
# 460     Bowl          Japan    5.0       NaN
# 490     Bowl    South Korea    5.0       NaN
# 547     Pack    Philippines    5.0       NaN
# 566     Bowl    South Korea    5.0       NaN
# 608     Pack      Singapore    5.0  2012 #10
# 639     Bowl          Japan    5.0       NaN
# 652     Pack          Japan    5.0       NaN
# 674     Pack    South Korea    5.0       NaN
# 700     Pack          Japan    5.0       NaN
# 715     Pack      Indonesia    5.0   2013 #3
# 723     Pack      Indonesia    5.0       NaN
# ...      ...            ...    ...       ...
# 2608    Pack  United States    5.0       NaN
# 2613    Bowl          Japan    5.0       NaN
# 2615    Pack      Hong Kong    5.0       NaN
# 2617     Cup      Singapore    5.0       NaN
# 2618    Pack      Singapore    5.0       NaN
# 2625    Pack      Singapore    5.0       NaN
# 2627    Bowl          Japan    5.0       NaN
# 2644    Pack    South Korea    5.0       NaN
# 2645    Pack         Taiwan    5.0       NaN
# 2651    Pack      Indonesia    5.0       NaN
# 2663    Pack      Indonesia    5.0       NaN
# 2672    Pack         Taiwan    5.0       NaN
# 2673    Pack      Hong Kong    5.0       NaN
# 2676    Bowl  United States    5.0       NaN
# 2679    Pack       Malaysia    5.0       NaN
# 2687    Tray          Japan    5.0       NaN
# 2688    Bowl      Singapore    5.0       NaN
# 2691    Pack      Hong Kong    5.0       NaN
# 2696     Cup  United States    5.0       NaN
# 2706    Pack         Taiwan    5.0       NaN
# 2708    Pack          China    5.0       NaN
# 2710    Pack          Japan    5.0       NaN
# 2712    Pack          India    5.0       NaN
# 2730    Bowl         Taiwan    5.0       NaN
# 2738    Pack         Taiwan    5.0       NaN
# 2741    Pack       Malaysia    5.0       NaN
# 2744    Pack          Japan    5.0       NaN
# 2745    Tray          Japan    5.0       NaN
# 2748    Pack       Malaysia    5.0       NaN
# 2750    Pack      Hong Kong    5.0       NaN
#
# [403 rows x 6 columns]

# %%
countries_5_stars = five_stars['country'].value_counts()

# %%
countries_5_stars
# Out:
# Japan            76
# Malaysia         57
# Taiwan           51
# South Korea      45
# Singapore        40
# United States    34
# Indonesia        25
# Hong Kong        22
# Thailand         18
# China            12
# UK                4
# Myanmar           4
# Philippines       2
# Canada            2
# India             2
# Cambodia          2
# Sarawak           1
# Nepal             1
# Australia         1
# Vietnam           1
# Mexico            1
# Germany           1
# Brazil            1
# Name: country, dtype: int64

# %%
country_list = five_stars['country'].unique()

# %%
country_list
# Out:
# array(['Japan', 'Indonesia', 'Thailand', 'Singapore', 'Taiwan',
#        'United States', 'Hong Kong', 'Philippines', 'South Korea',
#        'China', 'Malaysia', 'Nepal', 'UK', 'Canada', 'Myanmar', 'Sarawak',
#        'Cambodia', 'Brazil', 'Australia', 'India', 'Mexico', 'Vietnam',
#        'Germany'], dtype=object)

# %%
five_star_ratio = {}
for each in country_list:
    total_count = countries[each]
    five_count = countries_5_stars[each]
    five_star_ratio[each] = five_count / total_count

# %%
five_star_ratio
# Out:
# {'Japan': 0.19095477386934673,
#  'Indonesia': 0.1773049645390071,
#  'Thailand': 0.09375,
#  'Singapore': 0.31496062992125984,
#  'Taiwan': 0.21338912133891214,
#  'United States': 0.1,
#  'Hong Kong': 0.1506849315068493,
#  'Philippines': 0.0425531914893617,
#  'South Korea': 0.13719512195121952,
#  'China': 0.06666666666666667,
#  'Malaysia': 0.35625,
#  'Nepal': 0.07142857142857142,
#  'UK': 0.057971014492753624,
#  'Canada': 0.047619047619047616,
#  'Myanmar': 0.2857142857142857,
#  'Sarawak': 0.3333333333333333,
#  'Cambodia': 0.4,
#  'Brazil': 0.2,
#  'Australia': 0.045454545454545456,
#  'India': 0.04878048780487805,
#  'Mexico': 0.04,
#  'Vietnam': 0.00909090909090909,
#  'Germany': 0.037037037037037035}

# %%
plt.bar(range(len(five_star_ratio)),list(five_star_ratio.values()), align='center')
plt.xticks(range(len(five_star_ratio)),list(five_star_ratio.keys()))
plt.show()
