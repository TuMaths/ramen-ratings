# %%
import pandas

# %%
ramen_ratings = pandas.read_csv("ramen-ratings.csv")

# %%
print(ramen_ratings.head())
# Out:
#    review      brand                                         variety style  \
# 0    2750     Nissin  Cup Noodles Tom Yum Goong Flavour Potato Chips  Pack
# 1    2749   Maruchan                            Bariuma Goboten Udon  Bowl
# 2    2740     Meimen                         Hot & Sour Noodles Soup  Pack
# 3    2650      Paldo               Flaming Hot Savoury Cheese Noodle  Pack
# 4    1750  Mi Sedaap                   Instant Cup Mi Kuah Rasa Soto   Cup
#
#        country stars top_ten
# 0    Hong Kong     5     NaN
# 1        Japan     0     NaN
# 2       Taiwan  3.75     NaN
# 3  South Korea  4.25     NaN
# 4    Indonesia     5     NaN

# %%
print(ramen_ratings["country"])
# Out:
# 0           Hong Kong
# 1               Japan
# 2              Taiwan
# 3         South Korea
# 4           Indonesia
# 5            Thailand
# 6              Canada
# 7            Malaysia
# 8               Japan
# 9         Netherlands
# 10             Taiwan
# 11            Myanmar
# 12           Malaysia
# 13      United States
# 14          Singapore
# 15              China
# 16              Japan
# 17           Thailand
# 18          Indonesia
# 19           Malaysia
# 20              China
# 21          Singapore
# 22            Germany
# 23           Malaysia
# 24           Cambodia
# 25        South Korea
# 26             Taiwan
# 27             Taiwan
# 28              Japan
# 29             Taiwan
#             ...
# 2720            China
# 2721            China
# 2722            China
# 2723            China
# 2724            China
# 2725            China
# 2726            China
# 2727            China
# 2728        Indonesia
# 2729            China
# ...

# %%
countries = ramen_ratings["country"].tolist()

# %%
print(countries)
# Out:
# ['Hong Kong', 'Japan', 'Taiwan', 'South Korea', 'Indonesia', 'Thailand', 'Canada', 'Malaysia', 'Japan', 'Netherlands', 'Taiwan', 'Myanmar', 'Malaysia', 'United States', 'Singapore', 'China', 'Japan', 'Thailand', 'Indonesia', 'Malaysia', 'China', 'Singapore', 'Germany', 'Malaysia', 'Cambodia', 'South Korea', 'Taiwan', 'Taiwan', 'Japan', 'Taiwan', 'Vietnam', 'Taiwan', 'Finland', 'China', 'Malaysia', 'Indonesia', 'Japan', 'Malaysia', 'Thailand', 'Vietnam', 'Sarawak', 'Myanmar', 'Thailand', 'China', 'Malaysia', 'Japan', 'Malaysia', 'India', 'Taiwan', 'Hungary', 'Sarawak', 'Canada', 'Malaysia', 'Malaysia', 'China', 'Thailand', 'Japan', 'Japan', 'Taiwan', 'Taiwan', 'Malaysia', 'United States', 'Sarawak', 'Thailand', 'Thailand', 'Thailand', 'Myanmar', 'Bangladesh', 'Thailand', 'South Korea', 'China', 'China', 'China', 'China', 'China', 'China', 'China', 'China', 'China', 'China', 'Singapore', 'Malaysia', 'Taiwan', 'United States', 'South Korea', 'Malaysia', 'China', 'South Korea', 'Taiwan',
# ...
